# %% [markdown]
# 9. Write a program to implement Secured Hash Algorithm (SHA) one way hash function.

# %%
import hashlib


def sha1(data):
    return hashlib.sha1(data.encode()).hexdigest()


data = "Israk"
sha = sha1(data)
print(f"Original data: {data}")
print(f"Hash value: {sha}")
# Out:
# Original data: Israk
# Hash value: 0c4a0683989dad27665da64510a1835f4e616594
